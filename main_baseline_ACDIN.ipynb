# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from pathlib import Path
from scipy.io import loadmat
import re
import random
import os

# --- Import các module từ dự án của bạn ---
import cfg
# import trainer # Sẽ không dùng trainer.py gốc, mà dùng hàm tùy chỉnh bên dưới
from src import baseline_models, trainer, evaluate
from torch.utils.data import DataLoader, Dataset

# =====================================================================================
# PHẦN 1: LOGIC TẢI DỮ LIỆU THÔ (RAW DATA)
# Ghi chú: Tái sử dụng các hàm đã được xác nhận
# =====================================================================================

def get_label_from_path(file_path: Path) -> int:
    path_parts = file_path.parts
    if 'Normal' in path_parts: return 0
    elif 'IR' in path_parts: return 1
    elif 'OR' in path_parts: return 2
    return -1

def import_cwru_data_raw(file_keys: list, sample_length: int, base_path: str, overlapping_ratio: float = 0.0):
    all_samples, all_labels = [], []
    base_path_obj = Path(base_path)
    step = int(sample_length * (1 - overlapping_ratio))
    if step < 1: step = 1

    for key in file_keys:
        match = re.match(r'(\d+)(\w+)', key)
        if not match: continue
        file_num_str, data_key_suffix = match.groups()
        glob_pattern = f'{file_num_str}_*.mat'
        found_files = list(base_path_obj.rglob(glob_pattern))
        if not found_files: continue
        file_path = found_files[0]
        mat_data = loadmat(file_path)
        label = get_label_from_path(file_path)
        mat_key_zfill = f'X{file_num_str.zfill(3)}_{data_key_suffix}_time'
        mat_key_normal = f'X{file_num_str}_{data_key_suffix}_time'
        mat_key = mat_key_zfill if mat_key_zfill in mat_data else mat_key_normal
        if mat_key not in mat_data: continue
        time_series = mat_data[mat_key].flatten()
        for i in range(0, len(time_series) - sample_length + 1, step):
            all_samples.append(time_series[i : i + sample_length])
            all_labels.append(label)
    return np.array(all_samples), np.array(all_labels)

def data_import_raw(sample_length: int, overlapping_ratio: float, train_ratio=0.7, val_ratio=0.2):
    normal_files = ['97DE', '97FE', '98DE', '98FE', '99DE', '99FE', '100DE', '100FE']
    ir_files = ['211DE', '279DE', '274FE', '272DE', '272FE', '272BA', '209DE', '209FE', '210DE', '278DE', '278FE', '280DE', '280BA', '271DE', '271FE', '271BA', '276FE', '276BA', '277FE', '277BA', '212DE', '281DE', '275FE', '273DE', '273FE', '273BA']
    or_files = ['132DE', '146DE', '146FE', '146BA', '159DE', '312DE', '312FE', '315DE', '133DE', '147DE', '147FE', '147BA', '160DE', '317DE', '317FE', '317BA', '130DE', '131DE', '144DE', '144BA', '145DE', '145FE', '145BA', '156DE', '156FE', '310DE', '310FE', '309DE', '311DE', '311FE', '313DE', '313FE']
    data = [normal_files, ir_files, or_files]
    train_files, val_files, test_files = [], [], []
    for fault in data:
        random.shuffle(fault)
        n_samples = len(fault)
        train_end = int(train_ratio * n_samples)
        val_end = train_end + round(val_ratio * n_samples)
        train_files.extend(fault[:train_end]); val_files.extend(fault[train_end:val_end]); test_files.extend(fault[val_end:])
    X_train, Y_train = import_cwru_data_raw(train_files, sample_length, cfg.BASE_PATH, overlapping_ratio)
    X_val, Y_val = import_cwru_data_raw(val_files, sample_length, cfg.BASE_PATH, 0.0)
    X_test, Y_test = import_cwru_data_raw(test_files, sample_length, cfg.BASE_PATH, 0.0)
    return X_train, Y_train, X_val, Y_val, X_test, Y_test

class BearingDatasetRaw(Dataset):
    def __init__(self, X_data, Y_data, normalization=None):
        self.data = torch.from_numpy(X_data).float()
        self.labels = torch.from_numpy(Y_data).long()
        self.normalization = normalization
    def __len__(self): return len(self.data)
    def __getitem__(self, idx):
        sample = self.data[idx]
        if self.normalization == 'z-score':
            std = sample.std()
            if std > 1e-8: sample = (sample - sample.mean()) / std
        elif self.normalization == 'min-max':
            min_val, max_val = sample.min(), sample.max()
            range_val = max_val - min_val
            if range_val > 1e-8: sample = (sample - min_val) / range_val
        return sample.unsqueeze(0), self.labels[idx]

# =====================================================================================
# PHẦN 2: HÀM HUẤN LUYỆN TÙY CHỈNH CHO ACDIN
# =====================================================================================

def train_acdin_model(model, train_loader, val_loader, criterion, optimizer, output_name,
                      scheduler=None, num_epochs=100, device='cpu', 
                      early_stopping_patience=5, aux_loss_weight=0.3):
    model.to(device)
    best_val_acc = 0.0
    patience_counter = 0
    history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}

    for epoch in range(num_epochs):
        # --- Training phase ---
        model.train()
        running_loss, correct_train, total_train = 0, 0, 0
        
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            
            # ACDIN trả về 3 outputs khi training
            main_out, aux1_out, aux2_out = model(inputs)
            
            # Tính loss cho từng output
            loss_main = criterion(main_out, labels)
            loss_aux1 = criterion(aux1_out, labels)
            loss_aux2 = criterion(aux2_out, labels)
            
            # Tính loss tổng hợp
            total_loss = loss_main + aux_loss_weight * (loss_aux1 + loss_aux2)
            
            total_loss.backward()
            optimizer.step()
            
            running_loss += total_loss.item() * inputs.size(0)
            _, predicted = torch.max(main_out.data, 1) # Chỉ tính accuracy trên output chính
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
        
        epoch_loss = running_loss / total_train
        epoch_acc_train = 100.0 * correct_train / total_train
        history['train_loss'].append(epoch_loss)
        history['train_acc'].append(epoch_acc_train)
        
        # --- Validation phase ---
        model.eval()
        val_loss, correct_val, total_val = 0, 0, 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                # Khi eval, ACDIN chỉ trả về 1 output
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * inputs.size(0)
                _, predicted = torch.max(outputs.data, 1)
                total_val += labels.size(0)
                correct_val += (predicted == labels).sum().item()
        
        epoch_val_loss = val_loss / total_val
        epoch_acc_val = 100.0 * correct_val / total_val
        history['val_loss'].append(epoch_val_loss)
        history['val_acc'].append(epoch_acc_val)
        
        print(f"Epoch {epoch+1}/{num_epochs} | Train Loss: {epoch_loss:.4f} Acc: {epoch_acc_train:.2f}% | Val Loss: {epoch_val_loss:.4f} Acc: {epoch_acc_val:.2f}%")
        
        if epoch_acc_val > best_val_acc:
            best_val_acc = epoch_acc_val
            patience_counter = 0
            torch.save({'model_state_dict': model.state_dict()}, os.path.join('./outputs/models', output_name))
        else:
            patience_counter += 1
        
        if patience_counter >= early_stopping_patience:
            print(f"Early stopping at epoch {epoch+1}")
            break
        
        if scheduler: scheduler.step()

    return model, history

# =====================================================================================
# PHẦN 3: QUY TRÌNH HUẤN LUYỆN ACDIN
# =====================================================================================

if __name__ == '__main__':
    # 1. Thiết lập các tham số
    ACDIN_INPUT_LENGTH = 5120
    TRAIN_OVERLAPPING_RATIO = 0.95
    NORMALIZATION_METHOD = None # Tắt chuẩn hóa

    cfg.BATCH_SIZE = 32
    cfg.LEARNING_RATE = 1e-4

    accuracy_list= []
    for i in range(30):
        trainer.set_seed(i)
    
        # 2. Tải và chuẩn bị dữ liệu
        X_train, Y_train, X_val, Y_val, X_test, Y_test = data_import_raw(
            sample_length=ACDIN_INPUT_LENGTH,
            overlapping_ratio=TRAIN_OVERLAPPING_RATIO
        )
        
        train_dataset = BearingDatasetRaw(X_train, Y_train)
        val_dataset = BearingDatasetRaw(X_val, Y_val)
        test_dataset = BearingDatasetRaw(X_test, Y_test)
        
        train_loader = DataLoader(train_dataset, batch_size=cfg.BATCH_SIZE, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=cfg.BATCH_SIZE, shuffle=False)
        test_loader = DataLoader(test_dataset, batch_size=cfg.BATCH_SIZE, shuffle=False)


        # 3. Khởi tạo mô hình, optimizer, scheduler, loss
        model = baseline_models.ACDIN(input_channels=1, num_classes=cfg.NUM_CLASSES)
        model.to(cfg.DEVICE)
        
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.AdamW(model.parameters(), lr=5e-5, weight_decay=1e-5)
        scheduler = optim.lr_scheduler.CosineAnnealingLR(
            optimizer, T_max=cfg.NUM_EPOCHS, eta_min=5e-5 * 1e-2
        )


        trained_model, history = train_acdin_model(
            model=model, 
            train_loader=train_loader, 
            val_loader=val_loader, 
            criterion=criterion, 
            optimizer=optimizer, 
            output_name='acdin_best.pth', # Tên file lưu model
            scheduler=scheduler, 
            num_epochs= 10, 
            device=cfg.DEVICE,
            aux_loss_weight=0.3 # Trọng số cho loss phụ
        )

        accuracy = evaluate.plot_confusion_matrix(trained_model, test_loader, 'cpu', cfg.CLASS_NAMES)
        accuracy_list.append(accuracy)
        evaluate.plot_history(history)

    print('='*20)
    print('Mean accuracy:', np.mean(accuracy_list))
    print('Std accuracy:', np.std(accuracy_list))
# Out:
# Epoch 1/10 | Train Loss: 0.6394 Acc: 93.27% | Val Loss: 0.4944 Acc: 94.56%
# Epoch 2/10 | Train Loss: 0.1215 Acc: 99.98% | Val Loss: 0.6719 Acc: 94.10%
# Epoch 3/10 | Train Loss: 0.0704 Acc: 99.95% | Val Loss: 0.6203 Acc: 94.33%
# Epoch 4/10 | Train Loss: 0.0494 Acc: 100.00% | Val Loss: 0.5646 Acc: 94.56%
# Epoch 5/10 | Train Loss: 0.0355 Acc: 100.00% | Val Loss: 0.5570 Acc: 94.56%
# Epoch 6/10 | Train Loss: 0.0274 Acc: 99.92% | Val Loss: 0.5624 Acc: 94.78%
# Epoch 7/10 | Train Loss: 0.0138 Acc: 99.99% | Val Loss: 0.5419 Acc: 94.78%
# Epoch 8/10 | Train Loss: 0.0071 Acc: 100.00% | Val Loss: 0.5178 Acc: 94.78%
# Epoch 9/10 | Train Loss: 0.0037 Acc: 100.00% | Val Loss: 0.6483 Acc: 94.78%
# Epoch 10/10 | Train Loss: 0.0021 Acc: 100.00% | Val Loss: 0.6062 Acc: 94.78%
#  - Model accuracy: 100.00%
# Epoch 1/10 | Train Loss: 0.7245 Acc: 91.89% | Val Loss: 0.9038 Acc: 82.49%
# Epoch 2/10 | Train Loss: 0.2460 Acc: 99.71% | Val Loss: 0.6353 Acc: 89.09%
# Epoch 3/10 | Train Loss: 0.1126 Acc: 100.00% | Val Loss: 0.8164 Acc: 88.83%
# Epoch 4/10 | Train Loss: 0.0839 Acc: 99.98% | Val Loss: 0.5914 Acc: 92.39%
# Epoch 5/10 | Train Loss: 0.0694 Acc: 100.00% | Val Loss: 0.7959 Acc: 91.12%
# Epoch 6/10 | Train Loss: 0.0596 Acc: 100.00% | Val Loss: 0.7293 Acc: 91.88%
# Epoch 7/10 | Train Loss: 0.0511 Acc: 99.94% | Val Loss: 0.6681 Acc: 91.62%
# Epoch 8/10 | Train Loss: 0.0313 Acc: 100.00% | Val Loss: 0.6816 Acc: 93.40%
# Epoch 9/10 | Train Loss: 0.0141 Acc: 100.00% | Val Loss: 0.6759 Acc: 91.62%
# Epoch 10/10 | Train Loss: 0.0059 Acc: 100.00% | Val Loss: 0.8768 Acc: 90.10%
#  - Model accuracy: 100.00%
# Epoch 1/10 | Train Loss: 0.7752 Acc: 90.17% | Val Loss: 0.0044 Acc: 100.00%
# Epoch 2/10 | Train Loss: 0.2557 Acc: 99.74% | Val Loss: 0.0008 Acc: 100.00%
# Epoch 3/10 | Train Loss: 0.1132 Acc: 99.91% | Val Loss: 0.0001 Acc: 100.00%
# Epoch 4/10 | Train Loss: 0.0858 Acc: 99.97% | Val Loss: 0.0003 Acc: 100.00%
# Epoch 5/10 | Train Loss: 0.0744 Acc: 99.94% | Val Loss: 0.0002 Acc: 100.00%
# Epoch 6/10 | Train Loss: 0.0586 Acc: 100.00% | Val Loss: 0.0000 Acc: 100.00%
# Early stopping at epoch 6
#  - Model accuracy: 88.94%
# Epoch 1/10 | Train Loss: 0.7950 Acc: 89.65% | Val Loss: 0.5182 Acc: 89.57%
# Epoch 2/10 | Train Loss: 0.2845 Acc: 99.72% | Val Loss: 0.7581 Acc: 94.78%
# Epoch 3/10 | Train Loss: 0.1201 Acc: 99.93% | Val Loss: 0.6867 Acc: 94.78%
# Epoch 4/10 | Train Loss: 0.0848 Acc: 99.95% | Val Loss: 0.7282 Acc: 94.78%
# Epoch 5/10 | Train Loss: 0.0749 Acc: 99.97% | Val Loss: 0.5930 Acc: 94.78%
# Epoch 6/10 | Train Loss: 0.0673 Acc: 100.00% | Val Loss: 0.6716 Acc: 94.78%
# Epoch 7/10 | Train Loss: 0.0636 Acc: 99.95% | Val Loss: 0.8424 Acc: 94.78%
# Early stopping at epoch 7
#  - Model accuracy: 100.00%
# Epoch 1/10 | Train Loss: 0.7899 Acc: 89.86% | Val Loss: 0.0099 Acc: 100.00%
# Epoch 2/10 | Train Loss: 0.2968 Acc: 99.66% | Val Loss: 0.0034 Acc: 100.00%
# Epoch 3/10 | Train Loss: 0.1366 Acc: 99.92% | Val Loss: 0.0062 Acc: 99.75%
# Epoch 4/10 | Train Loss: 0.0856 Acc: 99.98% | Val Loss: 0.0003 Acc: 100.00%
# Epoch 5/10 | Train Loss: 0.0691 Acc: 100.00% | Val Loss: 0.0004 Acc: 100.00%
# Epoch 6/10 | Train Loss: 0.0546 Acc: 100.00% | Val Loss: 0.0002 Acc: 100.00%
# Early stopping at epoch 6
#  - Model accuracy: 100.00%
# Epoch 1/10 | Train Loss: 0.7540 Acc: 90.63% | Val Loss: 0.0779 Acc: 94.78%
# Epoch 2/10 | Train Loss: 0.2420 Acc: 99.62% | Val Loss: 0.0320 Acc: 97.96%
# Epoch 3/10 | Train Loss: 0.1139 Acc: 99.95% | Val Loss: 0.3200 Acc: 91.16%
# Epoch 4/10 | Train Loss: 0.0887 Acc: 99.99% | Val Loss: 0.0018 Acc: 100.00%
# Epoch 5/10 | Train Loss: 0.0868 Acc: 99.82% | Val Loss: 0.0451 Acc: 97.73%
# Epoch 6/10 | Train Loss: 0.0725 Acc: 99.99% | Val Loss: 0.0072 Acc: 99.77%
# Epoch 7/10 | Train Loss: 0.0692 Acc: 99.90% | Val Loss: 0.0826 Acc: 96.83%
# Epoch 8/10 | Train Loss: 0.0590 Acc: 100.00% | Val Loss: 0.0296 Acc: 98.19%
# Epoch 9/10 | Train Loss: 0.0482 Acc: 100.00% | Val Loss: 0.0017 Acc: 100.00%
# Early stopping at epoch 9
#  - Model accuracy: 99.61%
# Epoch 1/10 | Train Loss: 0.7532 Acc: 91.87% | Val Loss: 1.1309 Acc: 79.14%
# Epoch 2/10 | Train Loss: 0.2547 Acc: 99.62% | Val Loss: 2.2112 Acc: 79.14%
# Epoch 3/10 | Train Loss: 0.1196 Acc: 99.92% | Val Loss: 0.6731 Acc: 82.09%
# Epoch 4/10 | Train Loss: 0.0951 Acc: 100.00% | Val Loss: 0.1139 Acc: 95.69%
# Epoch 5/10 | Train Loss: 0.0873 Acc: 99.90% | Val Loss: 0.0631 Acc: 97.05%
# Epoch 6/10 | Train Loss: 0.0685 Acc: 99.99% | Val Loss: 0.0398 Acc: 98.64%
# Epoch 7/10 | Train Loss: 0.0469 Acc: 99.95% | Val Loss: 0.4961 Acc: 90.25%
# Epoch 8/10 | Train Loss: 0.0303 Acc: 100.00% | Val Loss: 0.2153 Acc: 93.88%
# Epoch 9/10 | Train Loss: 0.0232 Acc: 99.99% | Val Loss: 5.1386 Acc: 79.14%
# Epoch 10/10 | Train Loss: 0.0159 Acc: 99.96% | Val Loss: 3.0266 Acc: 79.14%
#  - Model accuracy: 100.00%
# Epoch 1/10 | Train Loss: 0.7641 Acc: 90.19% | Val Loss: 0.0197 Acc: 99.75%
# Epoch 2/10 | Train Loss: 0.2542 Acc: 99.59% | Val Loss: 0.0007 Acc: 100.00%
# Epoch 3/10 | Train Loss: 0.1174 Acc: 99.89% | Val Loss: 0.0008 Acc: 100.00%
# Epoch 4/10 | Train Loss: 0.0840 Acc: 99.97% | Val Loss: 0.0018 Acc: 100.00%
# Epoch 5/10 | Train Loss: 0.0770 Acc: 99.86% | Val Loss: 0.0015 Acc: 100.00%
# Epoch 6/10 | Train Loss: 0.0612 Acc: 99.96% | Val Loss: 0.0002 Acc: 100.00%
# Epoch 7/10 | Train Loss: 0.0471 Acc: 99.99% | Val Loss: 0.0001 Acc: 100.00%
# Early stopping at epoch 7
#  - Model accuracy: 99.61%
# Epoch 1/10 | Train Loss: 0.8182 Acc: 89.07% | Val Loss: 0.0247 Acc: 99.32%
# Epoch 2/10 | Train Loss: 0.3281 Acc: 99.65% | Val Loss: 0.0034 Acc: 100.00%
# Epoch 3/10 | Train Loss: 0.1656 Acc: 99.81% | Val Loss: 0.0000 Acc: 100.00%
# Epoch 4/10 | Train Loss: 0.1075 Acc: 99.97% | Val Loss: 0.0000 Acc: 100.00%
# Epoch 5/10 | Train Loss: 0.0990 Acc: 99.90% | Val Loss: 0.0000 Acc: 100.00%
# Epoch 6/10 | Train Loss: 0.0871 Acc: 99.99% | Val Loss: 0.0000 Acc: 100.00%
# Epoch 7/10 | Train Loss: 0.0838 Acc: 99.91% | Val Loss: 0.0000 Acc: 100.00%
# Early stopping at epoch 7
#  - Model accuracy: 100.00%
# Epoch 1/10 | Train Loss: 0.8175 Acc: 88.39% | Val Loss: 0.0873 Acc: 96.15%
# Epoch 2/10 | Train Loss: 0.3199 Acc: 99.65% | Val Loss: 0.0318 Acc: 98.87%
# Epoch 3/10 | Train Loss: 0.1601 Acc: 99.87% | Val Loss: 0.1034 Acc: 95.69%
# Epoch 4/10 | Train Loss: 0.1148 Acc: 99.94% | Val Loss: 0.0413 Acc: 98.87%
# Epoch 5/10 | Train Loss: 0.0909 Acc: 99.99% | Val Loss: 0.0428 Acc: 98.87%
# Epoch 6/10 | Train Loss: 0.0705 Acc: 99.96% | Val Loss: 0.6416 Acc: 89.57%
# Epoch 7/10 | Train Loss: 0.0530 Acc: 99.94% | Val Loss: 0.0585 Acc: 98.19%
# Early stopping at epoch 7
#  - Model accuracy: 100.00%
# Epoch 1/10 | Train Loss: 0.7006 Acc: 91.76% | Val Loss: 0.3889 Acc: 87.07%
# Epoch 2/10 | Train Loss: 0.2181 Acc: 99.93% | Val Loss: 0.2699 Acc: 88.66%
# Epoch 3/10 | Train Loss: 0.1005 Acc: 99.91% | Val Loss: 0.2989 Acc: 91.38%
# Epoch 4/10 | Train Loss: 0.0797 Acc: 99.99% | Val Loss: 0.5802 Acc: 88.44%
# Epoch 5/10 | Train Loss: 0.0680 Acc: 99.97% | Val Loss: 0.6800 Acc: 88.89%
# Epoch 6/10 | Train Loss: 0.0512 Acc: 100.00% | Val Loss: 0.4447 Acc: 89.34%
# Epoch 7/10 | Train Loss: 0.0263 Acc: 100.00% | Val Loss: 0.6693 Acc: 88.66%
# Epoch 8/10 | Train Loss: 0.0105 Acc: 100.00% | Val Loss: 0.3778 Acc: 93.88%
# Epoch 9/10 | Train Loss: 0.0050 Acc: 100.00% | Val Loss: 0.1826 Acc: 93.42%
# Epoch 10/10 | Train Loss: 0.0100 Acc: 99.89% | Val Loss: 0.0605 Acc: 96.15%
#  - Model accuracy: 93.27%
# Epoch 1/10 | Train Loss: 0.8076 Acc: 88.82% | Val Loss: 0.1140 Acc: 94.78%
# Epoch 2/10 | Train Loss: 0.3065 Acc: 99.71% | Val Loss: 0.0743 Acc: 96.15%
# Epoch 3/10 | Train Loss: 0.1343 Acc: 99.98% | Val Loss: 0.2509 Acc: 94.56%
# Epoch 4/10 | Train Loss: 0.1033 Acc: 99.89% | Val Loss: 0.4827 Acc: 94.78%
# Epoch 5/10 | Train Loss: 0.0827 Acc: 99.96% | Val Loss: 0.5502 Acc: 94.78%
# Epoch 6/10 | Train Loss: 0.0639 Acc: 99.94% | Val Loss: 0.4901 Acc: 94.33%
# Epoch 7/10 | Train Loss: 0.0413 Acc: 99.99% | Val Loss: 0.8123 Acc: 94.78%
# Early stopping at epoch 7
#  - Model accuracy: 90.98%
# Epoch 1/10 | Train Loss: 0.8054 Acc: 90.58% | Val Loss: 0.2332 Acc: 91.38%
# Epoch 2/10 | Train Loss: 0.3207 Acc: 99.76% | Val Loss: 0.0029 Acc: 100.00%
# Epoch 3/10 | Train Loss: 0.1446 Acc: 99.95% | Val Loss: 0.0128 Acc: 99.55%
# Epoch 4/10 | Train Loss: 0.1071 Acc: 99.86% | Val Loss: 0.0135 Acc: 99.32%
# Epoch 5/10 | Train Loss: 0.0913 Acc: 99.98% | Val Loss: 0.0341 Acc: 98.87%
# Epoch 6/10 | Train Loss: 0.0880 Acc: 99.85% | Val Loss: 0.0014 Acc: 100.00%
# Epoch 7/10 | Train Loss: 0.0740 Acc: 99.99% | Val Loss: 0.0017 Acc: 100.00%
# Early stopping at epoch 7
#  - Model accuracy: 100.00%
# Epoch 1/10 | Train Loss: 0.7055 Acc: 93.06% | Val Loss: 0.0092 Acc: 100.00%
# Epoch 2/10 | Train Loss: 0.2122 Acc: 99.77% | Val Loss: 0.0009 Acc: 100.00%
# Epoch 3/10 | Train Loss: 0.0978 Acc: 99.98% | Val Loss: 0.0428 Acc: 98.41%
# Epoch 4/10 | Train Loss: 0.0847 Acc: 99.91% | Val Loss: 0.0387 Acc: 98.64%
# Epoch 5/10 | Train Loss: 0.0715 Acc: 99.98% | Val Loss: 0.0640 Acc: 98.19%
# Epoch 6/10 | Train Loss: 0.0605 Acc: 99.95% | Val Loss: 0.1095 Acc: 97.28%
# Early stopping at epoch 6
#  - Model accuracy: 90.98%
# Epoch 1/10 | Train Loss: 0.7618 Acc: 90.26% | Val Loss: 0.0716 Acc: 95.01%
# Epoch 2/10 | Train Loss: 0.2442 Acc: 99.63% | Val Loss: 0.0014 Acc: 100.00%
# Epoch 3/10 | Train Loss: 0.1197 Acc: 99.96% | Val Loss: 0.2202 Acc: 95.01%
# Epoch 4/10 | Train Loss: 0.1022 Acc: 99.78% | Val Loss: 0.0086 Acc: 100.00%
# Epoch 5/10 | Train Loss: 0.0767 Acc: 100.00% | Val Loss: 0.0019 Acc: 100.00%
# Epoch 6/10 | Train Loss: 0.0653 Acc: 99.98% | Val Loss: 1.1668 Acc: 89.12%
# Epoch 7/10 | Train Loss: 0.0659 Acc: 99.84% | Val Loss: 0.0008 Acc: 100.00%
# Early stopping at epoch 7
#  - Model accuracy: 100.00%
# Epoch 1/10 | Train Loss: 0.7643 Acc: 92.09% | Val Loss: 1.5405 Acc: 70.81%
# Epoch 2/10 | Train Loss: 0.2852 Acc: 99.68% | Val Loss: 0.0064 Acc: 100.00%
# Epoch 3/10 | Train Loss: 0.1113 Acc: 99.97% | Val Loss: 0.0015 Acc: 100.00%
# Epoch 4/10 | Train Loss: 0.0665 Acc: 99.97% | Val Loss: 0.0005 Acc: 100.00%
# Epoch 5/10 | Train Loss: 0.0463 Acc: 100.00% | Val Loss: 0.0002 Acc: 100.00%
# Epoch 6/10 | Train Loss: 0.0343 Acc: 100.00% | Val Loss: 0.0001 Acc: 100.00%
# Epoch 7/10 | Train Loss: 0.0234 Acc: 100.00% | Val Loss: 0.0001 Acc: 100.00%
# Early stopping at epoch 7
#  - Model accuracy: 82.75%
# Epoch 1/10 | Train Loss: 0.7678 Acc: 91.79% | Val Loss: 0.6535 Acc: 89.12%
# Epoch 2/10 | Train Loss: 0.2674 Acc: 99.70% | Val Loss: 0.5038 Acc: 94.78%
# Epoch 3/10 | Train Loss: 0.1041 Acc: 99.84% | Val Loss: 0.3492 Acc: 94.78%
# Epoch 4/10 | Train Loss: 0.0754 Acc: 99.96% | Val Loss: 0.7158 Acc: 91.38%
# Epoch 5/10 | Train Loss: 0.0648 Acc: 99.94% | Val Loss: 0.8078 Acc: 93.42%
# Epoch 6/10 | Train Loss: 0.0545 Acc: 99.98% | Val Loss: 0.9313 Acc: 92.97%
# Epoch 7/10 | Train Loss: 0.0429 Acc: 100.00% | Val Loss: 0.7767 Acc: 94.10%
# Early stopping at epoch 7
#  - Model accuracy: 100.00%
# Epoch 1/10 | Train Loss: 0.7024 Acc: 92.24% | Val Loss: 0.0587 Acc: 96.83%
# Epoch 2/10 | Train Loss: 0.1574 Acc: 99.90% | Val Loss: 0.0214 Acc: 99.09%
# Epoch 3/10 | Train Loss: 0.0886 Acc: 99.96% | Val Loss: 0.0297 Acc: 98.41%
# Epoch 4/10 | Train Loss: 0.0702 Acc: 99.96% | Val Loss: 0.0187 Acc: 99.32%
# Epoch 5/10 | Train Loss: 0.0595 Acc: 99.95% | Val Loss: 0.0053 Acc: 99.77%
# Epoch 6/10 | Train Loss: 0.0478 Acc: 100.00% | Val Loss: 0.0282 Acc: 99.32%
# Epoch 7/10 | Train Loss: 0.0378 Acc: 100.00% | Val Loss: 0.0303 Acc: 98.64%
# Epoch 8/10 | Train Loss: 0.0304 Acc: 99.96% | Val Loss: 0.0116 Acc: 99.55%
# Epoch 9/10 | Train Loss: 0.0229 Acc: 99.98% | Val Loss: 0.1102 Acc: 97.51%
# Epoch 10/10 | Train Loss: 0.0181 Acc: 99.99% | Val Loss: 0.0546 Acc: 98.87%
# Early stopping at epoch 10
#  - Model accuracy: 90.98%
# Epoch 1/10 | Train Loss: 0.7067 Acc: 91.49% | Val Loss: 0.2142 Acc: 90.10%
# Epoch 2/10 | Train Loss: 0.1954 Acc: 99.89% | Val Loss: 0.4956 Acc: 94.16%
# Epoch 3/10 | Train Loss: 0.0976 Acc: 99.87% | Val Loss: 0.2388 Acc: 94.16%
# Epoch 4/10 | Train Loss: 0.0794 Acc: 99.99% | Val Loss: 0.5482 Acc: 94.16%
# Epoch 5/10 | Train Loss: 0.0684 Acc: 100.00% | Val Loss: 0.6369 Acc: 94.16%
# Epoch 6/10 | Train Loss: 0.0573 Acc: 99.92% | Val Loss: 0.6796 Acc: 94.16%
# Epoch 7/10 | Train Loss: 0.0387 Acc: 100.00% | Val Loss: 0.7736 Acc: 94.16%
# Early stopping at epoch 7
#  - Model accuracy: 81.96%
# Epoch 1/10 | Train Loss: 0.7582 Acc: 91.42% | Val Loss: 0.0244 Acc: 98.87%
# Epoch 2/10 | Train Loss: 0.2948 Acc: 99.50% | Val Loss: 0.0108 Acc: 99.77%
# Epoch 3/10 | Train Loss: 0.1472 Acc: 99.93% | Val Loss: 0.0032 Acc: 100.00%
# Epoch 4/10 | Train Loss: 0.1022 Acc: 99.93% | Val Loss: 0.0073 Acc: 99.77%
# Epoch 5/10 | Train Loss: 0.0844 Acc: 99.94% | Val Loss: 0.0135 Acc: 99.32%
# Epoch 6/10 | Train Loss: 0.0635 Acc: 99.94% | Val Loss: 0.0028 Acc: 100.00%
# Epoch 7/10 | Train Loss: 0.0390 Acc: 99.99% | Val Loss: 0.0007 Acc: 100.00%
# Epoch 8/10 | Train Loss: 0.0268 Acc: 99.92% | Val Loss: 0.0017 Acc: 100.00%
# Early stopping at epoch 8
#  - Model accuracy: 100.00%
# Epoch 1/10 | Train Loss: 0.7959 Acc: 90.23% | Val Loss: 0.0075 Acc: 100.00%
# Epoch 2/10 | Train Loss: 0.2713 Acc: 99.77% | Val Loss: 0.0013 Acc: 100.00%
# Epoch 3/10 | Train Loss: 0.1047 Acc: 99.97% | Val Loss: 0.0004 Acc: 100.00%
# Epoch 4/10 | Train Loss: 0.0794 Acc: 99.98% | Val Loss: 0.0011 Acc: 100.00%
# Epoch 5/10 | Train Loss: 0.0655 Acc: 100.00% | Val Loss: 0.0001 Acc: 100.00%
# Epoch 6/10 | Train Loss: 0.0539 Acc: 100.00% | Val Loss: 0.0002 Acc: 100.00%
# Early stopping at epoch 6
#  - Model accuracy: 90.98%
# Epoch 1/10 | Train Loss: 0.7814 Acc: 91.12% | Val Loss: 0.1612 Acc: 93.42%
# Epoch 2/10 | Train Loss: 0.3019 Acc: 99.74% | Val Loss: 0.2683 Acc: 94.78%
# Epoch 3/10 | Train Loss: 0.1170 Acc: 99.91% | Val Loss: 0.2304 Acc: 92.52%
# Epoch 4/10 | Train Loss: 0.0858 Acc: 100.00% | Val Loss: 0.5574 Acc: 94.78%
# Epoch 5/10 | Train Loss: 0.0752 Acc: 99.97% | Val Loss: 0.5801 Acc: 94.78%
# Epoch 6/10 | Train Loss: 0.0658 Acc: 100.00% | Val Loss: 0.6632 Acc: 94.78%
# Epoch 7/10 | Train Loss: 0.0593 Acc: 99.94% | Val Loss: 0.3586 Acc: 94.78%
# Early stopping at epoch 7
#  - Model accuracy: 81.96%
# Epoch 1/10 | Train Loss: 0.7896 Acc: 90.08% | Val Loss: 0.0454 Acc: 99.71%
# Epoch 2/10 | Train Loss: 0.2931 Acc: 99.47% | Val Loss: 0.0126 Acc: 99.71%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 213
#     207 optimizer = optim.AdamW(model.parameters(), lr=5e-5, weight_decay=1e-5)
#     208 scheduler = optim.lr_scheduler.CosineAnnealingLR(
#     209     optimizer, T_max=cfg.NUM_EPOCHS, eta_min=5e-5 * 1e-2
#     210 )
# --> 213 trained_model, history = train_acdin_model(
#     214     model=model,
#     215     train_loader=train_loader,
#     216     val_loader=val_loader,
#     217     criterion=criterion,
#     218     optimizer=optimizer,
#     219     output_name='acdin_best.pth', # Tên file lưu model
#     220     scheduler=scheduler,
#     221     num_epochs= 10,
#     222     device=cfg.DEVICE,
#     223     aux_loss_weight=0.3 # Trọng số cho loss phụ
#     224 )
#     226 accuracy = evaluate.plot_confusion_matrix(trained_model, test_loader, 'cpu', cfg.CLASS_NAMES)
#     227 accuracy_list.append(accuracy)
#
# Cell In[1], line 111, in train_acdin_model(model, train_loader, val_loader, criterion, optimizer, output_name, scheduler, num_epochs, device, early_stopping_patience, aux_loss_weight)
#     108 optimizer.zero_grad()
#     110 # ACDIN trả về 3 outputs khi training
# --> 111 main_out, aux1_out, aux2_out = model(inputs)
#     113 # Tính loss cho từng output
#     114 loss_main = criterion(main_out, labels)
#
# File ~/anaconda3/envs/khanh/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/khanh/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /home/HardDisk/Khanh/fault-detection-new/src/baseline_models.py:181, in ACDIN.forward(self, x)
#     178 x = self.pool4(x)
#     180 # Inception 3 & Aux 2
# --> 181 x = self.inception3b(self.inception3a(x))
#     182 if self.training:
#     183     aux2_out = self.aux2_fc(self.flatten(self.aux2_pool(x)))
#
# File ~/anaconda3/envs/khanh/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/khanh/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /home/HardDisk/Khanh/fault-detection-new/src/baseline_models.py:125, in InceptionModuleACDIN.forward(self, x)
#     124 def forward(self, x):
# --> 125     return torch.cat([self.branch1(x), self.branch2(x), self.branch3(x), self.branch4(x)], dim=1)
#
# File ~/anaconda3/envs/khanh/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/khanh/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/khanh/lib/python3.11/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File ~/anaconda3/envs/khanh/lib/python3.11/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/khanh/lib/python3.11/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/khanh/lib/python3.11/site-packages/torch/nn/modules/conv.py:375, in Conv1d.forward(self, input)
#     374 def forward(self, input: Tensor) -> Tensor:
# --> 375     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/anaconda3/envs/khanh/lib/python3.11/site-packages/torch/nn/modules/conv.py:370, in Conv1d._conv_forward(self, input, weight, bias)
#     358 if self.padding_mode != "zeros":
#     359     return F.conv1d(
#     360         F.pad(
#     361             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    368         self.groups,
#     369     )
# --> 370 return F.conv1d(
#     371     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     372 )
#
# KeyboardInterrupt:
