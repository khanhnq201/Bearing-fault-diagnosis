# %%
from src import baseline_models as md
from torchinfo import summary

model = md.Deeper1DCNN(1,3)
summary(model, input_size = (1,1,86))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# Deeper1DCNN                              [1, 3]                    --
# ├─Sequential: 1-1                        [1, 256, 21]              --
# │    └─Conv1d: 2-1                       [1, 64, 86]               256
# │    └─BatchNorm1d: 2-2                  [1, 64, 86]               128
# │    └─ReLU: 2-3                         [1, 64, 86]               --
# │    └─MaxPool1d: 2-4                    [1, 64, 43]               --
# │    └─Conv1d: 2-5                       [1, 128, 43]              24,704
# │    └─BatchNorm1d: 2-6                  [1, 128, 43]              256
# │    └─ReLU: 2-7                         [1, 128, 43]              --
# │    └─MaxPool1d: 2-8                    [1, 128, 21]              --
# │    └─Conv1d: 2-9                       [1, 256, 21]              98,560
# │    └─BatchNorm1d: 2-10                 [1, 256, 21]              512
# ...

# %%
model = md.Narrow_1DCNN(1,3)
summary(model, input_size = (1,1,86))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# Narrow_1DCNN                             [1, 3]                    --
# ├─Sequential: 1-1                        [1, 64, 1]                --
# │    └─Conv1d: 2-1                       [1, 32, 86]               128
# │    └─BatchNorm1d: 2-2                  [1, 32, 86]               64
# │    └─ReLU: 2-3                         [1, 32, 86]               --
# │    └─MaxPool1d: 2-4                    [1, 32, 43]               --
# │    └─Conv1d: 2-5                       [1, 64, 43]               6,208
# │    └─BatchNorm1d: 2-6                  [1, 64, 43]               128
# │    └─ReLU: 2-7                         [1, 64, 43]               --
# │    └─AdaptiveMaxPool1d: 2-8            [1, 64, 1]                --
# ├─Sequential: 1-2                        [1, 3]                    --
# │    └─Flatten: 2-9                      [1, 64]                   --
# ...

# %%
model = md.T_Model()
summary(model, input_size = (1,1,1024))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# T_Model                                  [1, 3]                    --
# ├─Sequential: 1-1                        [1, 512, 1024]            --
# │    └─T_BasicBlock: 2-1                 [1, 64, 1024]             --
# │    │    └─Sequential: 3-1              [1, 64, 1024]             4,544
# │    │    └─ReLU: 3-2                    [1, 64, 1024]             --
# │    └─T_BasicBlock: 2-2                 [1, 64, 1024]             --
# │    │    └─Sequential: 3-3              [1, 64, 1024]             16,640
# │    │    └─ReLU: 3-4                    [1, 64, 1024]             --
# │    └─T_BasicBlock: 2-3                 [1, 128, 1024]            --
# │    │    └─Sequential: 3-5              [1, 128, 1024]            41,472
# │    │    └─ReLU: 3-6                    [1, 128, 1024]            --
# │    └─T_BasicBlock: 2-4                 [1, 128, 1024]            --
# ...

# %%
model = md.WDCNN(1,3)
summary(model, input_size = (1,1,2048))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# WDCNN                                    [1, 3]                    --
# ├─Sequential: 1-1                        [1, 64, 3]                --
# │    └─Conv1d: 2-1                       [1, 16, 128]              1,040
# │    └─BatchNorm1d: 2-2                  [1, 16, 128]              32
# │    └─ReLU: 2-3                         [1, 16, 128]              --
# │    └─MaxPool1d: 2-4                    [1, 16, 64]               --
# │    └─Conv1d: 2-5                       [1, 32, 64]               1,568
# │    └─BatchNorm1d: 2-6                  [1, 32, 64]               64
# │    └─ReLU: 2-7                         [1, 32, 64]               --
# │    └─MaxPool1d: 2-8                    [1, 32, 32]               --
# │    └─Conv1d: 2-9                       [1, 64, 32]               6,208
# │    └─BatchNorm1d: 2-10                 [1, 64, 32]               128
# ...

# %%
model = md.ACDIN(1,3)
summary(model, input_size = (1,1,5120))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# ACDIN                                    [1, 3]                    2,118
# ├─Conv1d: 1-1                            [1, 64, 5118]             256
# ├─MaxPool1d: 1-2                         [1, 64, 1706]             --
# ├─Conv1d: 1-3                            [1, 128, 1704]            24,704
# ├─MaxPool1d: 1-4                         [1, 128, 568]             --
# ├─InceptionModuleACDIN: 1-5              [1, 176, 568]             --
# │    └─Conv1d: 2-1                       [1, 16, 568]              2,064
# │    └─Sequential: 2-2                   [1, 64, 568]              --
# │    │    └─Conv1d: 3-1                  [1, 16, 568]              2,064
# │    │    └─ReLU: 3-2                    [1, 16, 568]              --
# │    │    └─Conv1d: 3-3                  [1, 64, 568]              5,184
# │    └─Sequential: 2-3                   [1, 64, 568]              --
# ...

# %%
model = md.MobileNetV3_small_1D(1,3)
summary(model, input_size = (1,1,2048))
# Out:
# ...
# Layer (type:depth-idx)                             Output Shape              Param #
# ...
# MobileNetV3_small_1D                               [1, 3]                    --
# ├─Sequential: 1-1                                  [1, 576, 64]              --
# │    └─conv_block: 2-1                             [1, 16, 1024]             --
# │    │    └─Sequential: 3-1                        [1, 16, 1024]             80
# │    └─bottleneck: 2-2                             [1, 16, 512]              --
# │    │    └─Sequential: 3-2                        [1, 16, 512]              784
# │    └─bottleneck: 2-3                             [1, 24, 256]              --
# │    │    └─Sequential: 3-3                        [1, 24, 256]              3,432
# │    └─bottleneck: 2-4                             [1, 24, 256]              --
# │    │    └─Sequential: 3-4                        [1, 24, 256]              4,888
# │    └─bottleneck: 2-5                             [1, 40, 128]              --
# ...

# %%
import torch 
print("CUDA available:", torch.cuda.is_available())
# Out:
# CUDA available: True

# %%
import torch 
torch.__version__
# Out:
# '2.5.1'
